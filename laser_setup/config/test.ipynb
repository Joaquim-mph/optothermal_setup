# %%
import pyvisa
rm = pyvisa.ResourceManager()
print(rm.list_resources())
# Out:
# ('ASRL/dev/cu.wlan-debug::INSTR', 'ASRL/dev/cu.debug-console::INSTR', 'ASRL/dev/cu.Bluetooth-Incoming-Port::INSTR')
